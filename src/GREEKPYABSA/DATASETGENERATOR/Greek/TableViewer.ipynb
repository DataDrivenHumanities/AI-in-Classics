# %%
import random
import requests
import csv
import os
import pandas as pd
from bs4 import BeautifulSoup as bs
from urllib.parse import quote
import re
import unicodedata

#%run lib/GreekHelperFunctions.ipynb

# %run greek_lib/DatasetGenerator.ipynb
# %run greek_lib/DatasetFunctions.ipynb
# %run greek_lib/AtepcFunctions.ipynb
# %run greek_lib/ScentenceGeneration.ipynb
# %run greek_lib/TestGenerators.ipynb

#from urllib.request import urlopen
#pip install html5lib
#pip install lxml

# %%
#noun
print("NOUN")
noun_table = pd.read_csv("ancient_greek_variations/noun/ῥωμαῖος/second declension of ὁ ῥωμαῖος; τοῦ ῥωμαίου (attic)_inflection.csv",header=None).fillna('')

#verb
print("VERB")
verb_table = pd.read_csv("ancient_greek_variations/verb/μισέω/present- μῑσέω, μῑσέομαι (uncontracted)_inflection.csv",header=None).fillna('')

#adjective
print("ADJECTIVE")
adjective_table = pd.read_csv("ancient_greek_variations/adjective/κακός/first and second declension of κᾰκός; κᾰκή; κᾰκόν (attic)_declension.csv",header=None).fillna('')
table_array = [noun_table,verb_table,adjective_table]
display_list(table_array)

#i hate(indicative)(third person) romans(m)(p)
# romans are bad(masculine)(nominative)(plural)

#nouns
#plurality
#case

#verbs, 
#voice =active, midlle 
#mood = subjunctive indicative imperative
#person= first second third
#plurality= singular dual plural

#adjective

#verb
print("VERB")
verb_table = pd.read_csv("ancient_greek_variations/verb/μισέω/present- μῑσέω, μῑσέομαι (uncontracted)_inflection.csv",header=None).fillna('')
# Out:
# NOUN
# VERB
# ADJECTIVE
#            0                                                  1   \
# 0    Case / #                                           Singular
# 1  nominative                                          ὁ ῥωμαῖος
# 2    genitive                                        τοῦ ῥωμαίου
# 3      dative                                          τῷ ῥωμαίῳ
# 4  accusative                                        τὸν ῥωμαῖον
# 5    vocative                                             ῥωμαῖε
# 6      notes:  this table gives attic inflectional endings. f...
# 7      gender                                                  m
#
#                                                   2   \
# 0                                               Dual
# 1                                          τὼ ῥωμαίω
# 2                                      τοῖν ῥωμαίοιν
# 3                                      τοῖν ῥωμαίοιν
# 4                                          τὼ ῥωμαίω
# ...
