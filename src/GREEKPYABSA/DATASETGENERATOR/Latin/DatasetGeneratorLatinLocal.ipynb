# %%
# !pip install git+https://github.com/sjgallagher2/PyWORDS
import random
import requests
import csv
import os
import pandas as pd
from bs4 import BeautifulSoup as bs
from urllib.parse import quote
import re
import unicodedata
import pywords.lookup as lookup
#from urllib.request import urlopen
#pip install html5lib
#pip install lxml
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/sjgallagher2/PyWORDS
#   Cloning https://github.com/sjgallagher2/PyWORDS to /tmp/pip-req-build-kgd2eulz
#   Running command git clone --filter=blob:none --quiet https://github.com/sjgallagher2/PyWORDS /tmp/pip-req-build-kgd2eulz
#   Resolved https://github.com/sjgallagher2/PyWORDS to commit 1d962ff4942cacb0971827c62464efaf09c5867a
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from pywords==0.0.1) (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->pywords==0.0.1) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->pywords==0.0.1) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->pywords==0.0.1) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->pywords==0.0.1) (2.0.12)
# Building wheels for collected packages: pywords
#   Building wheel for pywords (pyproject.toml) ... done
#   Created wheel for pywords: filename=pywords-0.0.1-py3-none-any.whl size=1202286 sha256=86ddf2c92f423f91aa1b71020a1a4991d192e38ec84769dfa207e9005f218df7
#   Stored in directory: /tmp/pip-ephem-wheel-cache-8xz6msr4/wheels/58/87/e4/cb324fa54858598d49d28d8107d46daf58df985ea0bfba0e80
# Successfully built pywords
# Installing collected packages: pywords
# Successfully installed pywords-0.0.1

# %%
import pywords.lookup as lookup

word = 'lacedaemon'
# High level
lookup.lookup_word(word)  # Print matching words

# Lower level
# matches = lookup.match_word(word)
# for match in matches:
#      print(lookup.get_dictionary_string(match,full_info=True))

# %%
for match in lookup.match_word('graecum'): # Match possible words
    print(lookup.get_dictionary_string(match, False, True, False).split(' ')[0].replace(',',""))  # Start with the definition of the word
# Out:
# graecus

# %%
import os
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
PATH= 'drive/Shareddrives/AI in Classics/GreekABASAModel/DataSetGenerator'

os.chdir(PATH)# sets the current active directory to the current folder 
# !pwd
# IF YOU ENCOUNTER AN ERROR FIRST TRY RESTARTING RUNTIME
# Out:
# Mounted at /content/drive
# /content/drive/Shareddrives/AI in Classics/GreekABASAModel/DataSetGenerator

# %%
#test2 #allot easier proably just going to use this 
#creates inflections for nouns and adjectives
#creates conjugations for verbs
def strip_accents_and_lowercase(s):
   return ''.join(c for c in unicodedata.normalize('NFD', s)
                  if unicodedata.category(c) != 'Mn').lower()

    
def generate_variations(word,language='greek',show=False):
        # CREATES A FOLDER STRUCTURE THAT CONTAINS WORDS ORGANIZED BY PART OF SPEECH 
        #DECLINES WORDS 
        #test words
        #'Ῥωμαῖος' romans 
        #'μισώ' hate
        #'εἰμί' are to be
        #word = word.lower()

        for match in lookup.match_word(strip_accents_and_lowercase(word)):

           # Match possible words
           word = (lookup.get_dictionary_string(match, False, True, False).split(' ')[0].replace(',',""))
        
        with open("proper_names.txt", "r") as file:
          data = file.read()
          found = re.search(fr'(?i)\b{word}\b', data)
        
        if found:
          word = word.capitalize()
        
        #https://en.wiktionary.org/wiki/Ῥωμαῖος

        try:
          url= requests.get(f'https://en.wiktionary.org/wiki/{quote(word)}')
          soup = bs(url.text, 'html.parser')
          
          #remove unwanted classes
          for tag in soup.find_all('span',{'class':'tr Latn'}):
                  tag.decompose()
          for tag in soup.find_all('table',{'class':'audiotable'}):
                  tag.decompose()
          for tag in soup.find_all('sup'):
                  tag.decompose()
          
          #HEADERS ---------------------------
          #find all tables 
          tables =soup.find_all('table')
          h3 =[]
          h4 =[]
          nav=[]
          
          #DATAFRAMES----------------------------------

          dataframes = pd.read_html(soup.prettify())
          for i,df in enumerate(dataframes):
                  header = tables[i].find_previous('h2').text.replace('[edit]','').lower().strip()
                  if(header =='ancient greek'):
                          header = 'greek'
                  if(header != language):
                          h3.append('')
                          h4.append('')
                          nav.append('')
                          continue
                  if(tables[i].find_previous('h3')):
                          h3.append(tables[i].find_previous('h3').text
                          .replace('[edit]','')
                          .replace('\"','').lower().strip())
                  else:
                          h3.append('')
                  if(tables[i].find_previous('h4')):
                          h4.append(tables[i].find_previous('h4').text
                          .replace('[edit]','')
                          .replace('\"','').lower().strip())
                  else: 
                          h4.append('')
                  if(tables[i].find_previous('div',{'class':'NavHead'})):
                          nav.append(tables[i].find_previous('div',{'class':'NavHead'}).text
                          .replace('hide ▲','')
                          .replace('\"','').replace('/','-').replace(':','-').strip().lower())
                          #  : / mess up the file path so you need to remove them
                  else:
                          nav.append('')
                  ##display(df)
                  ##CREATE A FOLDER
                  root = f'{header}_variations'
                  os.makedirs(f'{root}/{h3[i]}/{word.lower()}/',exist_ok=True)
                  print(f'{root}/{h3[i]}/{word}/')
                  ##os.makedirs(nav[i],exist_ok=True)
                  
                  #print(h3[i])
                  #print(h4[i])
                  #print(nav[i])
                  #print('WRITE TO FILE--------------------------------')
                  
                  df=dataframes[i]
                  #display(df)
                  df=df.dropna(how='all',axis=0)
                  
                  df=df.drop(list(df.filter(regex = 'Unnamed')), axis = 1)
                  
                
                  df=df.replace({'➤':''}, regex=True)
                  df=df.replace({'•':''}, regex=True)
                  df=df.replace({'\[':'','\]':'','\{':'','\}':''}, regex=True)
                  df=df.replace({'—':' '}, regex=True)
                  #df=df.replace({'/':' ',r'\\':' '}, regex=True)
                  df=df.replace(r"\([^)]*\)","",regex=True)
                  
                          
                  
                  # make lowercase
                  df = df.applymap(lambda s: s.lower() if type(s) == str else s)
                  
                  #df = df.applymap(lambda s:strip_accents_and_lowercase(s) if type(s) == str else s)
                  df = df.applymap(lambda s: s.split(',', 1)[0] if type(s) == str else s)
                  df = df.applymap(lambda s: s.split('-', 1)[0] if type(s) == str else s)
                  df = df.applymap(lambda s: s.split('+', 1)[0] if type(s) == str else s)
                  df = df.applymap(lambda s: s.split('/', 1)[0] if type(s) == str else s)
                  df = df.applymap(lambda s: s.split('\\', 1)[0] if type(s) == str else s)
                        
                  df= df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
                  
                  
                  df = df.replace(r"\s\s+"," ",regex=True)
                  # NAN ARE REPALCED BY SPACE CHARACTER 
                  df.to_csv(f'{root}/{h3[i]}/{word.lower()}/{nav[i]}_{h4[i]}.csv',index=False)

                  if(show):display(df)
                
        except:
          print(f"{word} was not found")

          
          
                #print('READ FROM FILE ------------------------------------')
                #display(pd.read_csv(f'{root}/{h3[i]}/{word}/{nav[i]}_{h4[i]}.csv'))
        #----------------------------------
#generate_variations('Ῥωμαῖος','greek',show=True)

with open('proper_names.txt','r') as fin:
  lines = fin.readlines()
for line in lines:     
  generate_variations(line.rstrip(),'latin',show = False)   
                ## READ 
#test words
#'Ῥωμαῖος' romans 
#'μισώ' hate
#'εἰμί' is/are to be
#ελληνικά greeks
#odium hatred
#romanus
#odio hate
#απεχθάνομαι
#lacedaemon
        
# TO SHOW THE DATAFRAME PASS SHOW AS TRUE
# Out:
# Streaming output truncated to the last 5000 lines.
# latin_variations/proper noun/Sychaeus_/
# Sycurio was not found
# latin_variations/proper noun/Sycurium/
# Sydon was not found
# Sydracis was not found
# Sydrum was not found
# Syedris was not found
# Syenae was not found
# latin_variations/proper noun/Syene/
# Syenen was not found
# Syenes was not found
# Syenitae was not found
# latin_variations/proper noun/Syenites/
# Syfacis was not found
# Sygambram was not found
# Sygambri was not found
# Sygambris was not found
# Sygambros was not found
# Syhedris was not found
# Syl was not found
# Syll was not found
# Sylla was not found
# Syllae was not found
# Syllam was not found
# Syllani was not found
# Syllanis was not found
# Syllano was not found
# Syllanorum was not found
# Syllo was not found
# Syllum was not found
# Sylosontis was not found
# Syma was not found
# Symaetheas was not found
# Symaethia was not found
# Symaethide was not found
# Symaethius was not found
# Symaetho was not found
# Syme was not found
# Symiamira was not found
# Symiamirae was not found
# Symmacho was not found
# Symphoro was not found
# Symphorus was not found
# Symplegadas was not found
# Symplegade was not found
# Symplegades was not found
# Symplegados was not found
# Symplegas was not found
# symposiacus was not found
# Symposio was not found
# Syn was not found
# Synaristosis was not found
# Syncerasto was not found
# Syncerastum was not found
# Synephebis was not found
# Synephebos was not found
# Synhali was not found
# Synhalo was not found
# Synhalus was not found
# Synna was not found
# latin_variations/proper noun/Synnada/
# Synnade was not found
# Synnadense was not found
# Synnades was not found
# Synnadicus was not found
# Synnadis was not found
# Synnados was not found
# Sypha was not found
# Syphace was not found
# Syphacem was not found
# Syphacemque was not found
# Syphaci was not found
# Syphaci_nec was not found
# Syphacis was not found
# latin_variations/proper noun/Syphax/
# Syr was not found
# latin_variations/proper noun/Syra/
# Syracosia was not found
# Syracosias was not found
# Syracosio was not found
# Syracosius was not found
# Syracu was not found
# Syracusa was not found
# latin_variations/proper noun/Syracusae/
# Syracusana was not found
# Syracusanae was not found
# Syracusanam was not found
# Syracusanas was not found
# Syracusani was not found
# Syracusanis was not found
# Syracusanis_ was not found
# Syracusano was not found
# Syracusanorum was not found
# Syracusanos was not found
# Syracusanos_erant was not found
# Syracusanum was not found
# Syracusanus was not found
# Syracusarum was not found
# Syracusas was not found
# Syracusios was not found
# Syracusis was not found
# Syracusius was not found
# Syracusanorum was not found
# Syram was not found
# Syrasusis was not found
# Syre was not found
# Syrenas was not found
# Syri was not found
# latin_variations/proper noun/Syria/
# Syriaca was not found
# Syriacae was not found
# Syriacam was not found
# Syriacas was not found
# Syriaci was not found
# Syriacis was not found
# Syriaco was not found
# Syriacos was not found
# Syriacum was not found
# Syriacus was not found
# Syriae was not found
# Syriaeque was not found
# Syriaeque was not found
# Syriaeue was not found
# Syriam was not found
# Syriamque was not found
# Syrianam was not found
# Syriaque was not found
# Syriarum was not found
# Syrias was not found
# Syriaticae was not found
# Syriatici was not found
# Syriaticus was not found
# Syrico was not found
# Syricum was not found
# Syrien was not found
# Syriis was not found
# Syrio was not found
# Syrios was not found
# Syris was not found
# Syriscus was not found
# latin_variations/proper noun/Syrium/
# Syriumque was not found
# Syrius was not found
# latin_variations/proper noun/Syrnos/
# Syro was not found
# Syron was not found
# Syrophoenix was not found
# Syrorum was not found
# latin_variations/proper noun/Syros/
# Syrtis was not found
# Syrtis was not found
# Syrtis was not found
# Syrtica was not found
# Syrticae was not found
# Syrticam was not found
# Syrtico was not found
# Syrticus was not found
# Syrtidos was not found
# Syrtim was not found
# Syrtimque was not found
# Syrtis was not found
# Syrtis was not found
# Syru was not found
# Syrum was not found
# latin_variations/etymology 2/Syrus/
# latin_variations/etymology 3/Syrus/
# latin_variations/etymology 4/Syrus/
# latin_variations/etymology 2/Syrus/
# latin_variations/etymology 3/Syrus/
# latin_variations/etymology 4/Syrus/
# Sysinas was not found
# Tetrapus was not found
# Thalassa was not found
# Thymion was not found
# Tropetes was not found
# Ta was not found
# Tabas was not found
# latin_variations/noun/taberna/
# Tabim was not found
# latin_variations/noun/tabula/
# Taburni was not found
# Taburno was not found
# Taburnum was not found
# latin_variations/proper noun/Taburnus/
# latin_variations/proper noun/Tacape/
# latin_variations/proper noun/Tacatua/
# Tacfari was not found
# latin_variations/proper noun/Tacfarinas/
# Tacfarinate was not found
# Tacfarinatem was not found
# Tacfarinatis was not found
# Tachempso was not found
# Tacit was not found
# latin_variations/verb/taceo/
# latin_variations/verb/taceo/
# latin_variations/verb/taceo/
# latin_variations/verb/taceo/
# latin_variations/verb/taceo/
# latin_variations/verb/taceo/
# Tacompson was not found
# Tacompsos was not found
# latin_variations/proper noun/Tader/
# Tadi was not found
# Tadiana was not found
# Tadiano was not found
# Tadio was not found
# latin_variations/proper noun/Tadius/
# Tadu was not found
# Tae was not found
# Taena was not found
# Taenara was not found
# Taenari was not found
# Taenaria was not found
# Taenariae was not found
# Taenariam was not found
# Taenarias was not found
# Taenarides was not found
# Taenarii was not found
# Taenariis was not found
# Taenario was not found
# Taenaris was not found
# Taenarium was not found
# Taenariumque was not found
# Taenarius was not found
# Taenaro was not found
# Taenaron was not found
# Taenaros was not found
# Taenarum was not found
# latin_variations/proper noun/Taenarus/
# Taeneotica was not found
# Tagae was not found
# latin_variations/proper noun/Tages/
# Tagetis was not found
# Tagi was not found
# Tagique was not found
# Tago was not found
# Tagro was not found
# Tagum was not found
# Tagumque was not found
# latin_variations/proper noun/Tagus/
# Tagusue was not found
# Talabrica was not found
# Talai was not found
# Talaionides was not found
# Talandrum was not found
# Talao was not found
# Talarius was not found
# Talassio was not found
# Talassionem was not found
# Talassus was not found
# Talaum was not found
# latin_variations/proper noun/Talaus/
# latin_variations/adjective/talis/
# latin_variations/adjective/talis/
# Talna was not found
# Talnae was not found
# Talnam was not found
# Talon was not found
# Talthubi was not found
# Talthybioque was not found
# Talthybius was not found
# Talthybiusque was not found
# latin_variations/proper noun/Taludaei/
# Tam was not found
# Tama was not found
# Tamarci was not found
# latin_variations/noun/tamarix/
# latin_variations/proper noun/Tamaris/
# Tamasenum was not found
# Tame was not found
# Tamesae was not found
# Tamesim was not found
# latin_variations/proper noun/Tamesis/
# Tamo was not found
# Tamphilo was not found
# Tamphilum was not found
# latin_variations/proper noun/Tamphilus/
# Tampilus was not found
# Tamquam was not found
# latin_variations/proper noun/Tamuda/
# Tamum was not found
# Tamyris was not found
# Tana was not found
# latin_variations/proper noun/Tanagra/
# Tanagrae was not found
# Tanagraea was not found
# Tanagraeum was not found
# Tanagram was not found
# Tanagri was not found
# Tanagricos was not found
# Tanagricum was not found
# Tanai was not found
# Tanaim was not found
# Tanaimque was not found
# Tanain was not found
# Tanainque was not found
# latin_variations/proper noun/Tanais/
# Tanaisque was not found
# Tanaitas was not found
# Tanaitis was not found
# Tanaquil was not found
# Tanaquilis was not found
# Tanaum was not found
# Tanfanae was not found
# Tannetum was not found
# Tannonius was not found
# Tantalea was not found
# Tantaleae was not found
# Tantaleis was not found
# Tantaleo was not found
# Tantali was not found
# Tantalici was not found
# Tantalidae was not found
# Tantalidarum was not found
# Tantalide was not found
# Tantaliden was not found
# Tantalides was not found
# Tantalidos was not found
# Tantalidum was not found
# Tantalis was not found
# Tantalo was not found
# Tantalon was not found
# Tantalum was not found
# latin_variations/proper noun/Tantalus/
# Tantidem was not found
# Tanusii was not found
# Tanusiorum was not found
# latin_variations/proper noun/Tanusius/
# Tap was not found
# Taphi was not found
# latin_variations/proper noun/Taphiae/
# Taphiusa was not found
# Taphiusius was not found
# latin_variations/proper noun/Taphrae/
# latin_variations/noun/Taphros/
# Tapori was not found
# Taposiri was not found
# Taposirim was not found
# Tappo was not found
# Tappulam was not found
# Tappulo was not found
# latin_variations/proper noun/Tappulus/
# Tapro was not found
# latin_variations/proper noun/Taprobane/
# Taprobanen was not found
# Tapuris was not found
# Tapurorum was not found
# Tar was not found
# Taraciae was not found
# Taraciam was not found
# Tarae was not found
# Taranis was not found
# Tarans was not found
# Taras was not found
# Taratalla was not found
# latin_variations/proper noun/Tarbelli/
# Tarbellicus was not found
# Tarbellis was not found
# Tarcho was not found
# Tarchon was not found
# Tarchone was not found
# Tarchonem was not found
# Tarchonis was not found
# Tarchonte was not found
# Tarchontem was not found
# Tarcondimoto was not found
# latin_variations/proper noun/Tarcondimotus/
# latin_variations/adjective/tardus/
# latin_variations/adjective/tardipes/
# Taren was not found
# Tarenti was not found
# Tarentilla was not found
# Tarentina was not found
# Tarentinae was not found
# Tarentinaeque was not found
# Tarentinam was not found
# Tarentinarum was not found
# Tarentinas was not found
# Tarentini was not found
# Tarentinique was not found
# Tarentinis was not found
# Tarentino was not found
# Tarentinorum was not found
# Tarentinos was not found
# Tarentinum was not found
# Tarentinus was not found
# Tarento was not found
# Tarenton was not found
# Tarentos was not found
# latin_variations/proper noun/Tarentum/
# Tarentum_id was not found
# Tarentumque was not found
# Tarentus was not found
# Tarichaeas was not found
# latin_variations/proper noun/Tarichea/
# Taricheis was not found
# Tarii was not found
# latin_variations/proper noun/Tariona/
# Tariotarum was not found
# Tarium was not found
# latin_variations/proper noun/Tarius/
# Tarmiani was not found
# Tarmoendam was not found
# Tarneque was not found
# Tarni was not found
# latin_variations/proper noun/Tarpa/
# Tarpam was not found
# Tarpei was not found
# Tarpeia was not found
# Tarpeiae was not found
# Tarpeiam was not found
# Tarpeiamque was not found
# Tarpeianum was not found
# Tarpeiaque was not found
# Tarpeias was not found
# Tarpeii was not found
# Tarpeio was not found
# Tarpeios was not found
# Tarpeis was not found
# Tarpeium was not found
# latin_variations/proper noun/Tarpeius/
# latin_variations/adjective/Tarpeius/
# Tarquen was not found
# Tarqui was not found
# Tarquini was not found
# Tarquinia was not found
# Tarquiniana was not found
# Tarquiniense was not found
# Tarquiniensem was not found
# Tarquinienses was not found
# Tarquiniensesque was not found
# Tarquiniensi was not found
# Tarquiniensibus was not found
# Tarquiniensis was not found
# Tarquiniensisque was not found
# Tarquiniensium was not found
# latin_variations/proper noun/Tarquinii/
# Tarquiniique was not found
# Tarquiniis was not found
# Tarquiniis_nam was not found
# Tarquinio was not found
# Tarquiniorum was not found
# Tarquinios was not found
# Tarquinis was not found
# Tarquinium was not found
# latin_variations/proper noun/Tarquinius/
# latin_variations/adjective/Tarquinius/
# Tarquiniusque was not found
# Tarquitio was not found
# Tarquitique was not found
# Tarquitium was not found
# latin_variations/proper noun/Tarquitius/
# Tarquitum was not found
# Tarquini was not found
# Tarra was not found
# Tarracenses was not found
# latin_variations/proper noun/Tarracina/
# Tarracinae was not found
# Tarracinam was not found
# Tarracinenses was not found
# Tarracinensi was not found
# Tarracinensis was not found
# Tarracinensium was not found
# Tarraciniensibus was not found
# latin_variations/proper noun/Tarraco/
# latin_variations/proper noun/Tarracon/
# Tarracone was not found
# Tarraconem was not found
# Tarraconen was not found
# Tarraconense was not found
# Tarraconensem was not found
# Tarraconenses was not found
# Tarraconensi was not found
# Tarraconensia was not found
# latin_variations/adjective/Tarraconensis/
# Tarraconis was not found
# Tarraelios was not found
# Tarruteni was not found
# Tarsa was not found
# Tarsam was not found
# Tarsenses was not found
# Tarsensium was not found
# Tarsi was not found
# Tarso was not found
# Tarson was not found
# Tarsos was not found
# Tarsum was not found
# Tarsumennum was not found
# Tarta was not found
# Tartara was not found
# Tartarea was not found
# Tartareae was not found
# Tartaream was not found
# Tartareas was not found
# Tartarei was not found
# Tartareis was not found
# Tartareo was not found
# Tartareos was not found
# Tartareum was not found
# Tartareumque was not found
# Tartareus was not found
# Tartari was not found
# Tartaro was not found
# Tartaron was not found
# Tartarum was not found
# latin_variations/etymology 1/Tartarus/
# latin_variations/etymology 2/Tartarus/
# Tartesi was not found
# Tartesia was not found
# Tartesiaca was not found
# Tartesiacis was not found
# Tartesiacus was not found
# Tartesii was not found
# Tartesiorum was not found
# Tarteson was not found
# Tartesos was not found
# Tartessia was not found
# Tartessiacas was not found
# Tartessiacos was not found
# Tartessiorum was not found
# Tartessos was not found
# Tartessum was not found
# Tarulae was not found
# Tarusatium was not found
# latin_variations/proper noun/Tarutius/
# Taruisanis was not found
# Tasgetii was not found
# Tasgetium was not found
# latin_variations/proper noun/Tasgetius/
# Taso was not found
# latin_variations/proper noun/Tastris/
# Tasurci was not found
# Tatiae was not found
# Tatii was not found
# Tatio was not found
# Tatium was not found
# Tatiumque was not found
# Tatius was not found
# Tatnos was not found
# Tattaeus was not found
# Tauiana was not found
# Taulanti was not found
# Taulantia was not found
# latin_variations/proper noun/Taulantii/
# Taulantios was not found
# Taulantis was not found
# Taulantius was not found
# Taunum was not found
# Taunus was not found
# Taurania was not found
# Tauranus was not found
# Taurasinorum was not found
# Tauraunitium was not found
# latin_variations/adjective/taureus/
# latin_variations/adjective/taureus/
# latin_variations/adjective/taureus/
# latin_variations/adjective/taureus/
# latin_variations/adjective/taureus/
# Tauriana was not found
# Tauriani was not found
# Tauricam was not found
# Tauricana was not found
# Taurici was not found
# Tauricis was not found
# Tauricos was not found
# Tauridem was not found
# Taurii was not found
# Tauriis was not found
# latin_variations/adjective/taurinus/
# latin_variations/adjective/taurinus/
# latin_variations/adjective/taurinus/
# latin_variations/adjective/taurinus/
# latin_variations/adjective/taurinus/
# latin_variations/adjective/taurinus/
# latin_variations/adjective/taurinus/
# Taurios was not found
# Taurisci was not found
# Tauriscum was not found
# Tauroenta_quod was not found
# Tauroin was not found
# Tauromenita was not found
# Tauromenitana was not found
# Tauromenitanae was not found
# Tauromenitanam was not found
# Tauromenitani was not found
# Tauromenitanis was not found
# Tauromenitano was not found
# Tauromenitanum was not found
# latin_variations/proper noun/Tauromenium/
# Tauromenumque was not found
# Tauron was not found
# Tauroscythae was not found
# Tauroscythas was not found
# Taurubulae was not found
# Taurumue was not found
# Taueni was not found
# Tauium was not found
# latin_variations/etymology 1/taxo/
# latin_variations/etymology 2/taxo/
# Taxilen was not found
# Taxili was not found
# Taxilis was not found
# Taxilla was not found
# Tay was not found
# Taygete was not found
# Taygetenque was not found
# Taygeteque was not found
# Taygeti was not found
# Taygeto was not found
# Taygeton was not found
# Taygetorum was not found
# Taygetum was not found
# latin_variations/proper noun/Taygetus/
# Tu was not found
# teanus was not found
# teanus was not found
# teanus was not found
# latin_variations/proper noun/Teate/
# Teates was not found
# Tebarani was not found
# Tebassos was not found
# Tecmessae was not found
# Tecmessam was not found
# Tecmo was not found
# Tecmonem was not found
# tego was not found
# tego was not found
# tego was not found
# tego was not found
# latin_variations/proper noun/Tectosages/
# Tectosagis was not found
# Tectosagos was not found
# Tectosagum was not found
# Tedium was not found
# latin_variations/proper noun/Tegea/
# Tegeae was not found
# Tegeaea was not found
# Tegeaeae was not found
# Tegeaee was not found
# Tegeaeum was not found
# Tegeaeus was not found
# Tegeam was not found
# Tegeatarum was not found
# Tegeates was not found
# Tegeaticus was not found
# Tegeatide was not found
# Tegeatis was not found
# Tegee was not found
# Tegees was not found
# Tegeesque was not found
# Tegei was not found
# Tegeo was not found
# Tegeum was not found
# Tegula was not found
# Tei was not found
# Teia was not found
# Teii was not found
# Teio was not found
# Teiorum was not found
# Teios was not found
# Teium was not found
# Tel was not found
# Telum was not found
# Telamo was not found
# latin_variations/etymology 1/Telamon/
# latin_variations/etymology 2/Telamon/
# Telamona was not found
# Telamone was not found
# Telamonem was not found
# Telamoni was not found
# Telamonia was not found
# Telamoniade was not found
# Telamoniades was not found
# Telamonis was not found
# latin_variations/proper noun/Telamonius/
# Telamonque was not found
# Telau was not found
# Telchinas was not found
# latin_variations/proper noun/Telchines/
# Telchio was not found
# Telis was not found
# Teleboae was not found
# Teleboasque was not found
# Teleboides was not found
# Teleboum was not found
# Telecoonta was not found
# Telefum was not found
# Telefus was not found
# Telefus was not found
# Telegoni was not found
# Telegono was not found
# Telegonosque was not found
# Telegonum was not found
# Telegonus was not found
# Teleique was not found
# Telemachi was not found
# Telemacho was not found
# Telemachum was not found
# Telemachusque was not found
# Telemo was not found
# Telendena was not found
# Teleontis was not found
# Telephanen was not found
# Telephanes was not found
# Telephi was not found
# Telephi_ was not found
# Telepho was not found
# Telephum was not found
# Telephus was not found
# latin_variations/proper noun/Telesilla/
# Telesina was not found
# Telesinam was not found
# Telesini was not found
# Telesino was not found
# Telesinus was not found
# Telesphoro was not found
# Telesphorum was not found
# Teleste was not found
# Telesti was not found
# Telestidem was not found
# Telethrium was not found
# Telethusa was not found
# Telis was not found
# latin_variations/noun/Tellus/
# latin_variations/noun/Tellus/
# latin_variations/noun/Tellus/
# latin_variations/noun/Tellus/
# latin_variations/noun/Tellus/
# latin_variations/noun/Tellus/
# latin_variations/noun/Tellus/
# latin_variations/proper noun/Tellusa/
# Telmedium was not found
# Telmeso was not found
# Telmesos was not found
# Telmesses was not found
# Telmessicum was not found
# Telmessidos was not found
# Telmessii was not found
# Telmessium was not found
# Telmessum was not found
# Telmesum was not found
# Telmesus was not found
# Telum was not found
# Teloboarum was not found
# Teloboas was not found
# Telobois was not found
# Telon was not found
# Telo was not found
# Telphusiacaeque was not found
# Telum was not found
# Tem was not found
# Temarundam was not found
# Tembrogium was not found
# Temen was not found
# Temenites was not found
# Temenitida was not found
# Temenus was not found
# Temesaea was not found
# Temese was not found
# Temesesque was not found
# Temno was not found
# Temnites was not found
# Temno was not found
# Temnos was not found
# Temo was not found
# Tempani was not found
# Tempanio was not found
# Tempanium was not found
# latin_variations/noun/tempus/
# Tempe_is was not found
# Tempestas was not found
# Tempestas was not found
# latin_variations/noun/templum/
# latin_variations/noun/tempus/
# latin_variations/noun/tempus/
# Tempsa was not found
# Tempsae was not found
# Tempsano was not found
# Tempsanum was not found
# Tempsanus was not found
# Tempsin was not found
# Tempu was not found
# latin_variations/proper noun/Tempyra/
# Tenc was not found
# latin_variations/proper noun/Tencteri/
# Tencteris was not found
# Tencteros was not found
# Tencterum was not found
# Tencthe was not found
# Tenctheri was not found
# Tenctheris was not found
# Tenctherorum was not found
# Tendeba was not found
# latin_variations/etymology 1/tendo/
# latin_variations/etymology 1/tendo/
# latin_variations/etymology 2/tendo/
# Tenedia was not found
# Tenediam was not found
# Tenedios was not found
# Tenedo was not found
# Tenedon was not found
# Tenedonque was not found
# latin_variations/proper noun/Tenedos/
# Tenedum was not found
# latin_variations/proper noun/Tenedus/
# Tenen was not found
# latin_variations/verb/teneo/
# Tenon was not found
# latin_variations/proper noun/Tenos/
# Tenthredone was not found
# Tenthredonis was not found
# latin_variations/etymology 1/tendo/
# latin_variations/etymology 1/tendo/
# latin_variations/etymology 2/tendo/
# Tentyri was not found
# Tentyris was not found
# Tentyritae was not found
# Tenum was not found
# Tenupsis was not found
# Teo was not found
# Teon was not found
# Teos was not found
# Tepula was not found
# Tepulae was not found
# Tepulam was not found
# Tu was not found
# Tertius was not found
# latin_variations/proper noun/Teranei/
# tero was not found
# Terea was not found
# Tereaque was not found
# Terede was not found
# Teredon was not found
# Terei was not found
# Tereiana was not found
# Teren was not found
# tero was not found
# tero was not found
# tero was not found
# tero was not found
# Terentiae was not found
# Terentiam was not found
# Terentiana was not found
# Terentiano was not found
# Terentianum was not found
# Terentianus was not found
# Terentiei was not found
# Terentieis was not found
# Terentii was not found
# Terentilia was not found
# Terentilio was not found
# Terentillam was not found
# Terentina was not found
# Terentino was not found
# Terentinum was not found
# Terentio was not found
# tero was not found
# latin_variations/proper noun/Terentius/
# latin_variations/adjective/Terentius/
# Tereo was not found
# Tereos was not found
# Teresia was not found
# Teresiam was not found
# Teretinam was not found
# Tereum was not found
# latin_variations/proper noun/Tereus/
# Terg was not found
# latin_variations/noun/tergum/
# latin_variations/proper noun/Tergeste/
# Tergestinis was not found
# Tergestis was not found
# Tergestum was not found
# Terin was not found
# Terinaeum was not found
# Terinaeus was not found
# Terinam was not found
# Teriolte was not found
# Termestinae was not found
# Termestinorum was not found
# Termetis was not found
# Termi was not found
# Terminalis was not found
# Terminalis was not found
# Terminalis was not found
# Terminalis was not found
# latin_variations/noun/termen/
# Termino was not found
# Terpsichoren was not found
# latin_variations/proper noun/Terra/
# Terracinae was not found
# Terracinam was not found
# Terracinensem was not found
# Terraconensibus was not found
# latin_variations/proper noun/Terra/
# latin_variations/proper noun/Terra/
# latin_variations/proper noun/Terra/
# latin_variations/proper noun/Terra/
# latin_variations/proper noun/Terra/
# latin_variations/verb/terreo/
# latin_variations/proper noun/Terra/
# Tertius was not found
# Tertius was not found
# Tertius was not found
# Tertius was not found
# Tertius was not found
# Tertius was not found
# Tertius was not found
# Tertulla was not found
# Tertullae was not found
# Tertullam was not found
# Tertulliano was not found
# Tertullianum was not found
# latin_variations/etymology/Tertullianus/
# latin_variations/proper noun/Tertullianus/
# Tertullinus was not found
# Tertullo was not found
# Tertullum was not found
# Tertullus was not found
# latin_variations/noun/testum/
# latin_variations/proper noun/Testa/
# Testamentum was not found
# Testis was not found
# Testilis was not found
# Testis was not found
# Tethye was not found
# Tethyi was not found
# Tethyn was not found
# Tethynque was not found
# Tethyos was not found
# Tethysque was not found
# Tetraphyliam was not found
# latin_variations/adjective/teter/
# Tetricus was not found
# Tetricus was not found
# Tetricus was not found
# Tetricus was not found
# Tetricus was not found
# Tetricus was not found
# Tetricus was not found
# Tetrilius was not found
# Tetrinius was not found
# Tetti was not found
# Tettio was not found
# Tettium was not found
# latin_variations/proper noun/Tettius/
# Teu was not found
# Teuc was not found
# Teucer was not found
# Teucras was not found
# latin_variations/proper noun/Teucri/
# Teucria was not found
# Teucriadae was not found
# Teucriam was not found
# Teucrion was not found
# Teucrique was not found
# Teucris was not found
# Teucrisque was not found
# Teucro was not found
# Teucrorum was not found
# Teucros was not found
# Teucrosque was not found
# Teucrum was not found
# Teucrumque was not found
# Teum was not found
# Teumesi was not found
# Teumesia was not found
# Teumesius was not found
# Teumeson was not found
# latin_variations/proper noun/Teuta/
# Teutagono was not found
# Teutalus was not found
# Teutam was not found
# Teutana was not found
# Teutanes was not found
# Teutanis was not found
# Teutas was not found
# Teutates was not found
# Teuthra was not found
# Teuthrae was not found
# latin_variations/proper noun/Teuthrania/
# Teuthranie was not found
# Teuthrantem was not found
# Teuthranteusque was not found
# Teuthrantia was not found
# Teuthrantis was not found
# Teuthras was not found
# Teutobodus was not found
# Teutobur was not found
# latin_variations/proper noun/Teutomatus/
# Teutonas was not found
# Teutones was not found
# Teutoni was not found
# Teutonibusque was not found
# Teutonicae was not found
# Teutonicas was not found
# Teutonici was not found
# Teutonico was not found
# Teutonicos was not found
# Teutonicum was not found
# Teutonis was not found
# Teutonisque was not found
# Teutono was not found
# Teutonorum was not found
# Teutonos was not found
# Teutonum was not found
# Teutonus was not found
# Teutria was not found
# Th was not found
# Tha was not found
# latin_variations/proper noun/Thabraca/
# Thabusion was not found
# Thaemon was not found
# Thaida was not found
# Thaide was not found
# Thaidem was not found
# Thaidi was not found
# Thaidis was not found
# Thaidos was not found
# Thaini was not found
# latin_variations/noun/Thais/
# latin_variations/proper noun/Thala/
# Thalam was not found
# Thalassi was not found
# Thalassio was not found
# Thale was not found
# Thalea was not found
# Thalem was not found
# Thalen was not found
# Thalestrin was not found
# Thalestris was not found
# Thaleta was not found
# Thalete was not found
# Thaletem was not found
# Thaleti was not found
# Thaletis was not found
# Thaliae was not found
# Thaliam was not found
# Thaliarche was not found
# Thallus was not found
# Thallus was not found
# Thallus was not found
# Thallus was not found
# Thallus was not found
# latin_variations/proper noun/Thalna/
# Thalos was not found
# Thalpius was not found
# Thalysiades was not found
# Thamar was not found
# Thamari was not found
# Thamaris was not found
# Thamyrae was not found
# Thamyram was not found
# Thamyran was not found
# Thamyras was not found
# Thamyrim was not found
# Thamyrin was not found
# Thamyris was not found
# Thamyrum was not found
# Thamyrumque was not found
# Thanar was not found
# Thapsi was not found
# Thapsitanis was not found
# Thapsitanos was not found
# Thapso was not found
# Thapson was not found
# Thapsonque was not found
# latin_variations/proper noun/Thapsos/
# Thapsum was not found
# Thapsumque was not found
# latin_variations/proper noun/Thapsus/
# Tharne was not found
# Tharnen was not found
# Tharria was not found
# Tharsimachi was not found
# Thasi was not found
# Thasia was not found
# Thasiae was not found
# Thasiam was not found
# Thasie was not found
# Thasii was not found
# Thasio was not found
# Thasios was not found
# Thasium was not found
# Thasius was not found
# Thaso was not found
# latin_variations/proper noun/Thasos/
# Thasosque was not found
# Thasoue was not found
# Thasum was not found
# Thasumque was not found
# Thaticen was not found
# Thau was not found
# Thaumaci was not found
# Thaumacis was not found
# Thaumacum was not found
# Thaumante was not found
# Thaumantea was not found
# Thaumantias was not found
# Thaumantida was not found
# Thaumantide was not found
# Thaumantidos was not found
# Thaumantis was not found
# Thaumas was not found
# Thaumasia was not found
# Theaeteto was not found
# Theano was not found
# Theanus was not found
# Theb was not found
# Theba was not found
# latin_variations/proper noun/Thebae/
# Thebaeque was not found
# Thebai was not found
# Thebaica was not found
# Thebaicae was not found
# Thebaicaeue was not found
# Thebaicas was not found
# Thebaici was not found
# Thebaico was not found
# Thebaicum was not found
# Thebaicus was not found
# Thebaide was not found
# Thebaidem was not found
# Thebaides was not found
# Thebaidi was not found
# Thebaidis was not found
# Thebaidos was not found
# Thebais was not found
# Thebaite was not found
# Thebana was not found
# Thebanae was not found
# Thebanam was not found
# Thebanaque was not found
# Thebanasque was not found
# Thebane was not found
# latin_variations/proper noun/Thebani/
# Thebanique was not found
# Thebanis was not found
# Thebano was not found
# Thebanorum was not found
# Thebanos was not found
# Thebanum was not found
# Thebanus was not found
# Thebarum was not found
# Thebarumque was not found
# Thebas was not found
# latin_variations/proper noun/Thebasa/
# Thebasque was not found
# Theben was not found
# Thebi was not found
# Thebis was not found
# Thebogene was not found
# Thebri was not found
# Thebrim was not found
# Theclam was not found
# Theganusa was not found
# Thelgon was not found
# Thelxinoe was not found
# Thely was not found
# Thelyphron was not found
# Themi was not found
# Themide was not found
# Themidis was not found
# Themillae was not found
# Themin was not found
# Themiscyrae was not found
# Themiscyrei was not found
# Themiscyrena was not found
# Themiso was not found
# Themison was not found
# Themisone was not found
# Themisoni was not found
# Themisonis was not found
# Themista was not found
# Themisteas was not found
# Themisti was not found
# Themisti_nam was not found
# latin_variations/proper noun/Themisto/
# Themistocle was not found
# Themistoclea was not found
# Themistoclem was not found
# Themistoclen was not found
# Themistocleo was not found
# latin_variations/proper noun/Themistocles/
# Themistocleum was not found
# Themistocli was not found
# Themistoclis was not found
# Themistonem was not found
# Themistum was not found
# Thena was not found
# Thenas was not found
# thensaurus was not found
# Thensaurochrysonicochrysides was not found
# Theo was not found
# Theobulae was not found
# Theobules was not found
# Theocliam was not found
# Theocriti was not found
# Theocritiae was not found
# Theocritio was not found
# Theocritium was not found
# Theocrito was not found
# Theocritum was not found
# latin_variations/proper noun/Theocritus/
# Theodamantis was not found
# Theodec was not found
# Theodectes was not found
# Theodecti was not found
# Theodectis was not found
# Theodorei was not found
# Theodoreus was not found
# Theodori was not found
# Theodoro was not found
# Theodoromedes was not found
# Theodorum was not found
# latin_variations/proper noun/Theodorus/
# latin_variations/proper noun/Theodosia/
# Theodoti was not found
# Theodotius was not found
# Theodoto was not found
# Theodotum was not found
# Theodotus was not found
# Theofane was not found
# Theogenes was not found
# Theognidis was not found
# Theologumenon was not found
# Theomnasti was not found
# Theomnasto was not found
# Theomnastum was not found
# Theomnastus was not found
# Theomnesto was not found
# Theon was not found
# Theona was not found
# Theonda was not found
# Theonino was not found
# Theonis was not found
# Theonoe was not found
# Theonoen was not found
# Theop was not found
# Theophane was not found
# Theophanem was not found
# Theophanen was not found
# Theophanes was not found
# Theophani was not found
# Theophanis was not found
# Theophila was not found
# Theophilum was not found
# latin_variations/proper noun/Theophilus/
# Theophra was not found
# Theophras was not found
# Theophrasti was not found
# Theophrasto was not found
# Theophrastum was not found
# latin_variations/proper noun/Theophrastus/
# Theopompeoque was not found
# Theopompi was not found
# Theopompo was not found
# Theopompum was not found
# latin_variations/proper noun/Theopompus/
# Theopropidem was not found
# latin_variations/proper noun/Theopropides/
# Theoti was not found
# Theotimo was not found
# Theotimum was not found
# Theotimus was not found
# Theotisca was not found
# Theoxenus was not found
# Ther was not found
# latin_variations/proper noun/Thera/
# Therae was not found
# Theraei was not found
# Theraeo was not found
# Theramene was not found
# Theramenem was not found
# latin_variations/proper noun/Theramenes/
# Theramenis was not found
# latin_variations/proper noun/Therapnae/
# Therapnaea was not found
# Therapnaeae was not found
# Therapnaei was not found
# Therapnaeis was not found
# Therapnaeo was not found
# Therapne was not found
# Therapnis was not found
# Therapontigono was not found
# latin_variations/proper noun/Therapontigonus/
# Therasia was not found
# Therasiam was not found
# Therbeeo was not found
# Thereaque was not found
# Thericlia was not found
# Theridamas was not found
# Therimachus was not found
# Therinos was not found
# Theriphone was not found
# latin_variations/noun/therma/
# Thermaico was not found
# Thermaicus was not found
# latin_variations/noun/therma/
# latin_variations/noun/therma/
# Thermi was not found
# Thermiaeos was not found
# latin_variations/noun/therma/
# Thermitani was not found
# Thermitanis was not found
# Thermitanorum was not found
# Thermitanorum was not found
# Thermitanus was not found
# Thermo was not found
# latin_variations/proper noun/Thermodon/
# Thermodonta was not found
# Thermodontem was not found
# Thermodontiaca was not found
# Thermodontiacae was not found
# Thermodontiaco was not found
# Thermodontiae was not found
# Thermodontiis was not found
# Thermodontis was not found
# Thermodoontem was not found
# Thermop was not found
# Thermopuleis was not found
# Thermopy was not found
# Thermopyla was not found
# latin_variations/proper noun/Thermopylae/
# Thermopylarum was not found
# Thermopylas was not found
# Thermopylis was not found
# latin_variations/proper noun/Thermum/
# latin_variations/proper noun/Thermus/
# Theromedon was not found
# Therona was not found
# Therone was not found
# Theronis was not found
# Therothoas was not found
# Thersander was not found
# Therses was not found
# Thersippus was not found
# Thersit was not found
# Thersitae was not found
# Thersitam was not found
# Thersite was not found
# Thersiten was not found
# Thersites was not found
# Thes was not found
# latin_variations/noun/thesaurus/
# Thescelus was not found
# latin_variations/noun/thesis/
# Thesea was not found
# Theseae was not found
# Theseaque was not found
# Thesei was not found
# Theseia was not found
# Theseide was not found
# Theseis was not found
# Theseius was not found
# Theseo was not found
# Theseos was not found
# Theseu was not found
# Theseum was not found
# latin_variations/proper noun/Theseus/
# latin_variations/adjective/Theseus/
# Theseus_nisi was not found
# Theseusque was not found
# latin_variations/proper noun/Theseus/
# latin_variations/adjective/Theseus/
# Thesidae was not found
# Thesmopho was not found
# Thesmophoria was not found
# Thespi was not found
# Thespia was not found
# Thespiaca was not found
# Thespiacis was not found
# Thespiadae was not found
# Thespiadas was not found
# Thespiaden was not found
# Thespiades was not found
# Thespiadu was not found
# Thespiadum was not found
# latin_variations/proper noun/Thespiae/
# Thespias was not found
# Thespiensis was not found
# Thespii was not found
# Thespiis was not found
# Thespio was not found
# latin_variations/proper noun/Thespis/
# Thespius was not found
# Thesprionem was not found
# Thespro was not found
# latin_variations/proper noun/Thesproti/
# latin_variations/proper noun/Thesprotia/
# Thesprotiae was not found
# Thesprotius was not found
# Thesprotu was not found
# Thesprotum was not found
# Thess was not found
# Thessa was not found
# Thessal was not found
# Thessala was not found
# Thessalae was not found
# Thessalam was not found
# Thessalas was not found
# Thessali was not found
# latin_variations/proper noun/Thessalia/
# Thessaliae was not found
# Thessaliam was not found
# Thessaliaque was not found
# Thessalica was not found
# Thessalicae was not found
# Thessalicam was not found
# Thessalicas was not found
# Thessalici was not found
# Thessalicis was not found
# Thessalico was not found
# Thessalicos was not found
# Thessalicum was not found
# Thessalicus was not found
# Thessalicusque was not found
# Thessalidum was not found
# Thessalis was not found
# Thessalo was not found
# Thessaloche was not found
# Thessaloni was not found
# latin_variations/proper noun/Thessalonica/
# Thessalonicae was not found
# Thessalonicam was not found
# Thessalonice was not found
# Thessalonicen was not found
# Thessalonicenses was not found
# Thessalorum was not found
# Thessalorumque was not found
# Thessalos was not found
# Thessalosque was not found
# Thessalum was not found
# latin_variations/adjective/Thessalus/
# latin_variations/noun/Thessalus/
# latin_variations/adjective/Thessalus_/
# latin_variations/noun/Thessalus_/
# Thessandrum was not found
# Thessandrus was not found
# Thestiadae was not found
# Thestiaden was not found
# Thestiados was not found
# Thestias was not found
# Thestii was not found
# latin_variations/proper noun/Thestor/
# Thestorem was not found
# Thestoride was not found
# Thestoriden was not found
# Thestorides was not found
# Thestoris was not found
# Thestylide was not found
# latin_variations/proper noun/Thestylis/
# latin_variations/proper noun/Thestylis/
# Theti was not found
# Thetide was not found
# Thetideius was not found
# Thetideum was not found
# Thetidi was not found
# Thetidique was not found
# Thetidis was not found
# Thetim was not found
# Thetin was not found
# Thettalos was not found
# Thetys was not found
# Theudae was not found
# Theudalis was not found
# Theudoriam was not found
# Theudotus was not found
# Theuprosopon was not found
# Thiae was not found
# latin_variations/noun/thiasus/
# Thimaneos was not found
# Thiodamanta was not found
# Thiodamas was not found
# Thirmida was not found
# Thisbaeas was not found
# latin_variations/proper noun/Thisbe/
# Thisben was not found
# Thisbes was not found
# Tho was not found
# Thoactes was not found
# Thoan was not found
# Thoanta was not found
# Thoante was not found
# Thoanteae was not found
# Thoantem was not found
# Thoanti was not found
# Thoantias was not found
# Thoantida was not found
# Thoantis was not found
# Thoar was not found
# Thoas was not found
# Thoasque was not found
# Thocari was not found
# Thoe was not found
# Thoen was not found
# latin_variations/proper noun/Thomna/
# Thoonem was not found
# Thoos was not found
# Thoosae was not found
# Thoria was not found
# Thoricos was not found
# latin_variations/proper noun/Thorius/
# latin_variations/adjective/Thorius/
# Thoti was not found
# Thous was not found
# Thr was not found
# Thra was not found
# Thrac was not found
# Thraca was not found
# Thracas was not found
# Thracem was not found
# Thracen was not found
# Thraces was not found
# Thraci was not found
# latin_variations/proper noun/Thracia/
# Thraciae was not found
# Thraciae_et was not found
# Thraciam was not found
# Thraciaque was not found
# Thraciarum was not found
# Thracias was not found
# Thracibus was not found
# Thracici was not found
# Thracicos was not found
# Thracicum was not found
# Thraciis was not found
# Thracio was not found
# Thracios was not found
# Thracis was not found
# Thracisce was not found
# Thracium was not found
# Thracius was not found
# Thraco was not found
# Thracum was not found
# Thracum_ was not found
# Thracumque was not found
# Thracus was not found
# Thracum was not found
# Thrae was not found
# Thraeca was not found
# Thraecae was not found
# Thraecam was not found
# Thraecas was not found
# Thraece was not found
# Thraecem was not found
# Thraeces was not found
# Thraecia was not found
# Thraeciae was not found
# Thraeciam was not found
# Thraecibus was not found
# Thraecica was not found
# Thraecidicis was not found
# Thraeciis was not found
# Thraecio was not found
# Thraecis was not found
# Thraecum was not found
# Thraessa was not found
# latin_variations/noun/Thraex/
# latin_variations/proper noun/Thrasea/
# Thraseae was not found
# Thraseam was not found
# Thrasippo was not found
# Thrasippum was not found
# Thrasius was not found
# Thraso was not found
# Thrasone was not found
# Thrasoni was not found
# Thrasul was not found
# Thrasulli was not found
# Thrasullus was not found
# Thrasy was not found
# Thrasybuli was not found
# Thrasybulo was not found
# Thrasybulum was not found
# latin_variations/proper noun/Thrasybulus/
# Thrasyl was not found
# Thrasyleon was not found
# Thrasylli was not found
# Thrasyllo was not found
# Thrasyllum was not found
# Thrasyllus was not found
# Thrasymacho was not found
# Thrasymachum was not found
# Thrasymachus was not found
# Thrasymennum was not found
# Thrausi was not found
# latin_variations/adjective/Thrax/
# latin_variations/noun/Thrax/
# Threces was not found
# Threci was not found
# Threcia was not found
# Threciae was not found
# Threciam was not found
# Threcibus was not found
# Threcidicae was not found
# Threcum was not found
# Threi was not found
# Threicia was not found
# Threiciae was not found
# Threiciamque was not found
# Threicias was not found
# Threicii was not found
# Threiciis was not found
# Threicio was not found
# Threicios was not found
# Threicium was not found
# latin_variations/adjective/Threicius/
# Threissa was not found
# Thressa was not found
# Thressae was not found
# Thressaeque was not found
# Thressam was not found
# Thressas was not found
# Threx was not found
# Thriare was not found
# Thriasiis was not found
# Thriasius was not found
# latin_variations/proper noun/Thronium/
# Thryon was not found
# latin_variations/proper noun/Thubuscum/
# Thucy was not found
# Thucydi was not found
# Thucydid was not found
# Thucydidas was not found
# Thucydide was not found
# Thucydidem was not found
# Thucydiden was not found
# Thucydideo was not found
# latin_variations/proper noun/Thucydides/
# Thucydidi was not found
# Thucydidis was not found
# latin_variations/proper noun/Thule/
# Thulin was not found
# latin_variations/noun/thus/
# Thurias was not found
# latin_variations/proper noun/Thurii/
# Thuriis was not found
# Thurin was not found
# Thurina was not found
# Thurinae was not found
# Thurini was not found
# Thurinis was not found
# Thurino was not found
# Thurinorum was not found
# Thurinos was not found
# Thurinum was not found
# Thurios was not found
# Thurri was not found
# Thuyn was not found
# Thuynem was not found
# Thuyni was not found
# Thuys was not found
# Thy was not found
# Thya was not found
# Thyades was not found
# Thyamim was not found
# latin_variations/proper noun/Thyatira/
# Thyatiram was not found
# Thyatireni was not found
# Thybri was not found
# Thybride was not found
# Thybridis was not found
# Thybrim was not found
# Thybrimque was not found
# Thybrin was not found
# Thybrina was not found
# latin_variations/proper noun/Thybris/
# latin_variations/proper noun/Thydonos/
# Thydrum was not found
# Thyes was not found
# Thyesta was not found
# Thyestae was not found
# Thyeste was not found
# Thyestea was not found
# Thyesteae was not found
# Thyesteas was not found
# Thyesteis was not found
# Thyestem was not found
# Thyesten was not found
# Thyesteo was not found
# Thyestes was not found
# Thyesti was not found
# Thyestiaden was not found
# Thyestis was not found
# Thyiada was not found
# Thyiadas was not found
# Thyiades was not found
# thyia was not found
# Thyillus was not found
# Thyillusque was not found
# Thyle was not found
# Thylen was not found
# Thyles was not found
# Thym was not found
# Thymberque was not found
# Thymbra was not found
# Thymbra was not found
# Thymbraee was not found
# Thymbraei was not found
# Thymbraeo was not found
# Thymbraeum was not found
# Thymbraeus was not found
# Thymbre was not found
# Thymbreo was not found
# Thymele was not found
# Thymelen was not found
# Thymeles was not found
# latin_variations/proper noun/Thymnias/
# latin_variations/etymology 1/thymum/
# Thymodes was not found
# Thymoeta was not found
# Thymoeten was not found
# Thymoetes was not found
# Thyn was not found
# Thyneaque was not found
# Thyneius was not found
# Thyni was not found
# Thyniam was not found
# Thynian was not found
# latin_variations/proper noun/Thynias/
# Thyniasin was not found
# Thynis was not found
# Thynos was not found
# Thyonae was not found
# Thyone was not found
# Thyoneo was not found
# Thyoneus was not found
# Thyoneus was not found
# Thyonianus was not found
# Thyotes was not found
# Thyreae was not found
# Thyreatida was not found
# Thyreatium was not found
# latin_variations/proper noun/Thyrides/
# Thyrmis was not found
# Thyrreensis was not found
# Thyrrei was not found
# Thyrreo was not found
# Thyrreum was not found
# Thyrsaget was not found
# Thyrsagetas was not found
# latin_variations/noun/thyrsus/
# Thyrside was not found
# Thyrsin was not found
# latin_variations/noun/thyrsus/
# Thyrum was not found
# Thysdrae was not found
# Thysdram was not found
# Thysdritanum was not found
# Thysdrum was not found
# latin_variations/proper noun/Thyssagetae/
# Thyssanusa was not found
# Ti was not found
# Tianorum was not found
# latin_variations/noun/tiara/
# Tib was not found
# latin_variations/proper noun/Tibareni/
# Tibarenum was not found
# Tibe was not found
# Tiberi was not found
# Tiberiade was not found
# Tiberiana was not found
# Tiberianae was not found
# Tiberianam was not found
# Tiberiano was not found
# Tiberianus was not found
# Tiberii was not found
# Tiberim was not found
# Tiberimque was not found
# Tiberin was not found
# Tiberina was not found
# Tiberinaque was not found
# Tiberine was not found
# Tiberini was not found
# Tiberinides was not found
# Tiberinis was not found
# Tiberino was not found
# Tiberinum was not found
# Tiberinus was not found
# Tiberio was not found
# Tiberiolus was not found
# latin_variations/proper noun/Tiberis/
# Tiberisque was not found
# Tiberium was not found
# latin_variations/proper noun/Tiberius/
# Tiberiusque was not found
# Tu was not found
# Tibicen was not found
# Tibri was not found
# Tibul was not found
# Tibulle was not found
# Tibulli was not found
# Tibullo was not found
# Tibullum was not found
# latin_variations/proper noun/Tibullus/
# latin_variations/proper noun/Tibur/
# Tibure was not found
# Tiburi was not found
# Tiburis was not found
# Tiburna was not found
# Tiburnae was not found
# Tiburne was not found
# Tiburni was not found
# Tiburno was not found
# Tiburnus was not found
# Tiburque was not found
# Tiburs was not found
# Tiburs_ was not found
# Tiburte was not found
# Tiburtem was not found
# Tiburtes was not found
# Tiburti was not found
# Tiburtia was not found
# Tiburtibus was not found
# Tiburtina was not found
# Tiburtinae was not found
# Tiburtinam was not found
# Tiburtinas was not found
# Tiburtini was not found
# Tiburtinis was not found
# Tiburtino was not found
# Tiburtinorum was not found
# Tiburtinos was not found
# Tiburtinum was not found
# Tiburtinus was not found
# Tiburtis was not found
# Tiburtium was not found
# Tiburtum was not found
# Tiburtus was not found
# latin_variations/proper noun/Tibur/
# Tibure was not found
# Ticer was not found
# Tichi was not found
# Tichiunta was not found
# Tichiunta_haec was not found
# Tichos was not found
# latin_variations/proper noun/Ticida/
# Ticidae was not found
# Ticidam was not found
# Ticina was not found
# Ticini was not found
# Ticiniensi was not found
# Ticinum was not found
# latin_variations/proper noun/Ticinus/
# Ticis was not found
# Tifata was not found
# Tifatis was not found
# Tifer was not found
# Tiferni was not found
# Tiferno was not found
# Tifernum was not found
# Tigelli was not found
# Tigellini was not found
# Tigellino was not found
# Tigellinum was not found
# Tigellinus was not found
# Tigellio was not found
# Tigellium was not found
# latin_variations/proper noun/Tigellius/
# Tigil was not found
# latin_variations/noun/tigillum/
# Tigillini was not found
# Tigillinum was not found
# Tigillio was not found
# Tigra was not found
# Tigrane was not found
# Tigranem was not found
# Tigranemque was not found
# Tigranen was not found
# latin_variations/proper noun/Tigranes/
# Tigrani was not found
# Tigranis was not found
# Tigrano was not found
# Tigranocerta was not found
# Tigranocertam was not found
# Tigranocertis was not found
# tigrisis was not found
# tigrisis was not found
# tigrisis was not found
# tigrisis was not found
# Tigrim was not found
# tigrisis was not found
# tigrisis was not found
# Tigu was not found
# Tigulia was not found
# Tiguliorum was not found
# Tigurini was not found
# Tigurinorum was not found
# Tigurinum was not found
# Tillio was not found
# Tillium was not found
# Tim was not found
# Timaeo was not found
# Timaeum was not found
# Timaeus was not found
# Timagene was not found
# latin_variations/proper noun/Timagenes/
# Timageni was not found
# Timagora was not found
# Timagorae was not found
# Timagoran was not found
# Timagoras was not found
# Timandram was not found
# Timanthe was not found
# Timanthem was not found
# Timanthes was not found
# Timanthi was not found
# Timar was not found
# Timarchide was not found
# Timarchidem was not found
# Timarchides was not found
# Timarchidi was not found
# Timarcho was not found
# Timarchum was not found
# latin_variations/proper noun/Timarete/
# Timaridis was not found
# Timaristo was not found
# Timarum was not found
# Timasicrates was not found
# ...
# Uiriatho was not found
# Uiriathum was not found
# Uiriathus was not found
# Uiriato was not found
# Uiriatum was not found
# Uiriatus was not found
# Uiridomaro was not found
# Uiridomarum was not found
# Uiridomarus was not found
# Uiridouice was not found
# Uiridouicem was not found
# Uiridouix was not found
# latin_variations/adjective/virilis/
# latin_variations/adjective/virilis/
# Uirilitatis was not found
# Uiriplacae was not found
# Uiritus was not found
# Uiromanduis was not found
# Uiromanduos was not found
# Uirouesca was not found
# Uirrius was not found
# Uirro was not found
# Uirronem was not found
# Uirronibus was not found
# Uirronis was not found
# latin_variations/noun/virtus/
# latin_variations/noun/virtus/
# latin_variations/noun/virtus/
# latin_variations/noun/virtus/
# latin_variations/noun/virtus/
# latin_variations/noun/virtus/
# latin_variations/noun/virtus/
# latin_variations/noun/virtus/
# latin_variations/noun/vir/
# latin_variations/noun/vir/
# Uirunum was not found
# Uiruo was not found
# latin_variations/etymology 1/vis/
# latin_variations/verb/video/
# visco was not found
# latin_variations/noun/viscum/
# latin_variations/noun/viscum/
# latin_variations/noun/viscus/
# latin_variations/verb/video/
# Uiselli was not found
# Uisellia was not found
# Uisellius was not found
# latin_variations/noun/vispillo/
# Uistilia was not found
# Uistiliae was not found
# Uistilio was not found
# Uistla was not found
# Uistula was not found
# Uisurgim was not found
# Uisurgin was not found
# Uisurgis was not found
# latin_variations/verb/vito/
# Uitalianum was not found
# Uitalianus was not found
# latin_variations/noun/vita/
# Uitel was not found
# vitellum was not found
# Uitellia was not found
# Uitelliam was not found
# Uitellianae was not found
# Uitellianam was not found
# Uitellianarum was not found
# Uitellianas was not found
# Uitelliani was not found
# Uitellianis was not found
# Uitelliano was not found
# Uitellianorum was not found
# Uitellianos was not found
# Uitellianum was not found
# Uitellianus was not found
# Uitellii was not found
# Uitellio was not found
# Uitelliorum was not found
# Uitellios was not found
# vitellum was not found
# Uitellium was not found
# Uitellius was not found
# latin_variations/etymology 1/vitio/
# Uitori was not found
# Uitr was not found
# Uitrasia was not found
# Uitrasius was not found
# Uitru was not found
# Uitruuia was not found
# Uitruuium was not found
# Uitruuius was not found
# latin_variations/noun/vitula/
# Uitularia was not found
# latin_variations/noun/vitulus/
# latin_variations/noun/vitulus/
# latin_variations/noun/vitulus/
# latin_variations/noun/vitulus/
# Uituriga was not found
# latin_variations/verb/vivo/
# Uliaros was not found
# Ulixe was not found
# Ulixeam was not found
# Ulixei was not found
# Ulixem was not found
# Ulixen was not found
# latin_variations/proper noun/Ulixes/
# Ulixi was not found
# Ulixis was not found
# Ulpica was not found
# Ulubris was not found
# Ulubris was not found
# Ulyxe was not found
# Umber was not found
# latin_variations/proper noun/Umbro/
# Umbriae was not found
# Umbriam was not found
# Umbriaque was not found
# Umbrica was not found
# Umbricius was not found
# latin_variations/proper noun/Umbro/
# Umbronem was not found
# latin_variations/proper noun/Umbro/
# Umbros was not found
# latin_variations/adjective/umidus/
# Ummidii was not found
# Ummidio was not found
# Ummidium was not found
# Unus was not found
# latin_variations/verb/undo/
# Undecumanorum was not found
# latin_variations/adjective/unimanus/
# Uoc was not found
# Uoccionis was not found
# latin_variations/noun/vox/
# Uocetium was not found
# latin_variations/verb/voco/
# Uocon was not found
# Uoconi was not found
# Uoconia was not found
# Uoconiae was not found
# Uoconiam was not found
# Uoconiam_ was not found
# Uoconio was not found
# Uoconius was not found
# Uoconti was not found
# Uocontia was not found
# Uocontiorum was not found
# Uocontiorum was not found
# latin_variations/noun/vocula/
# latin_variations/noun/vocula/
# latin_variations/noun/vocula/
# Uol was not found
# latin_variations/etymology 1/volo/
# latin_variations/etymology 2/volo/
# Uolaginium was not found
# Uolaminiam was not found
# latin_variations/etymology 1/volo/
# latin_variations/etymology 2/volo/
# latin_variations/etymology 1/volo/
# latin_variations/etymology 2/volo/
# Uolanerius was not found
# Uolaterrana was not found
# Uolaterrani was not found
# Uolaterranis was not found
# Uolaterrano was not found
# Uolaterranorum was not found
# Uolaterranos was not found
# Uolaterranum was not found
# Uolaterras was not found
# Uolaterris was not found
# Uolcaci was not found
# Uolcacio was not found
# Uolcacium was not found
# Uolcacius was not found
# Uolcanali was not found
# Uolcanalibus was not found
# Uolcanaliorum was not found
# Uolcani was not found
# Uolcania was not found
# Uolcaniae was not found
# Uolcaniaque was not found
# Uolcaniis was not found
# Uolcanius was not found
# Uolcano was not found
# Uolcanom was not found
# Uolcanum was not found
# Uolcanus was not found
# Uolcarum was not found
# Uolcas was not found
# Uolcatio was not found
# Uolcatium was not found
# Uolcatius was not found
# Uolcens was not found
# Uolcente was not found
# Uolcentem was not found
# Uolcientium was not found
# Uolcis was not found
# Uolero was not found
# Uolerone was not found
# Uolesi was not found
# Uoleso was not found
# Uolesos was not found
# Uolesum was not found
# Uolesus was not found
# Uolicanus was not found
# Uolkanalia was not found
# Uolnius was not found
# latin_variations/etymology 1/volo/
# latin_variations/etymology 2/volo/
# Uologaesi was not found
# Uologaeso was not found
# Uologaesum was not found
# Uologaesus was not found
# Uologese was not found
# Uologesen was not found
# Uologeses was not found
# Uologesi was not found
# Uologesis was not found
# Uologesocertam was not found
# Uologessus was not found
# Uologesus was not found
# Uolsca was not found
# Uolscam was not found
# Uolscatibus was not found
# Uolsce was not found
# Uolsci was not found
# Uolscis was not found
# Uolsco was not found
# Uolscorum was not found
# Uolscos was not found
# Uolsini was not found
# Uolsiniensem was not found
# Uolsiniensis was not found
# Uolsiniensium was not found
# Uolsinii was not found
# Uolsiniis was not found
# Uolsinios was not found
# Uolsinis was not found
# latin_variations/verb/vello/
# Uolsonem was not found
# Uolsonis was not found
# Uolt was not found
# Uolteio was not found
# Uolteium was not found
# Uolteium was not found
# Uoltinia was not found
# Uoltiniam was not found
# Uoltiniensis was not found
# latin_variations/noun/voltur/
# Uolturci was not found
# Uolturcio was not found
# Uolturcium was not found
# Uolturcius was not found
# latin_variations/noun/voltur/
# latin_variations/noun/voltur/
# Uolturni was not found
# Uolturno was not found
# Uolturnum was not found
# Uolturnus was not found
# Uoluce was not found
# Uolucem was not found
# latin_variations/noun/volucris/
# latin_variations/noun/volucris/
# latin_variations/noun/volucris/
# latin_variations/noun/volucris/
# Uolum was not found
# Uolumni was not found
# Uolumnia was not found
# Uolumniam was not found
# Uolumnii was not found
# Uolumnio was not found
# Uolumnium was not found
# Uolumnius was not found
# Uolunx was not found
# Uolupiae was not found
# Uolupta was not found
# latin_variations/noun/voluptas/
# latin_variations/noun/voluptas/
# latin_variations/noun/voluptas/
# latin_variations/noun/voluptas/
# latin_variations/noun/voluptas/
# Uoluseno was not found
# Uolusenum was not found
# Uolusenus was not found
# Uolusi was not found
# Uolusiano was not found
# Uolusii was not found
# Uolusio was not found
# Uolusium was not found
# Uolusius was not found
# Uolux was not found
# Uomano was not found
# Uomanum was not found
# Uonone was not found
# Uononem was not found
# Uononen was not found
# Uonones was not found
# Uononi was not found
# Uononis was not found
# Uopisci was not found
# Uopisco was not found
# Uopiscus was not found
# Uoranus was not found
# Uoranus was not found
# Uorapte was not found
# Uorenus was not found
# Uorsibus was not found
# Uortumni was not found
# Uortumnum was not found
# Uortumnus was not found
#  was not found
# Uosegi was not found
# Uosego was not found
# Uosegus was not found
# latin_variations/verb/voveo/
# Uotieni was not found
# Uotieno was not found
# Uotienus was not found
# latin_variations/verb/voveo/
# latin_variations/verb/voveo/
# Uranie was not found
# latin_variations/proper noun/Uranopolis/
# latin_variations/proper noun/Urbanus/
# latin_variations/proper noun/Urbanus/
# latin_variations/proper noun/Urbanus/
# latin_variations/proper noun/Urbanus/
# Urbiano was not found
# Urbinas was not found
# Urbini was not found
# Urbinia was not found
# Urbiniae was not found
# Urbiniana was not found
# Urci was not found
# latin_variations/verb/urgeo/
# latin_variations/proper noun/Urgo/
# Urgu was not found
# Urgulania was not found
# Urgulaniae was not found
# Urgulaniam was not found
# Urgulanilla was not found
# latin_variations/proper noun/Uria/
# Uriona was not found
# Urium was not found
# Urna was not found
# Ursidio was not found
# latin_variations/noun/ursus/
# latin_variations/noun/ursus/
# Usi was not found
# Usidicani was not found
# latin_variations/proper noun/Usipetes/
# Usiporum was not found
# Usipos was not found
# Uspen was not found
# Uspensium was not found
# Usticae was not found
# Uthinam was not found
# latin_variations/proper noun/Utica/
# Uticae was not found
# Uticam was not found
# Uticense was not found
# Uticensem was not found
# Uticenses was not found
# Uticensis was not found
# Utin was not found
# latin_variations/proper noun/Utis/
# Uul was not found
# Uulca was not found
# Uulcacius was not found
# Uulcanalia was not found
# Uulcanalibus was not found
# Uulcanaliorum was not found
# Uulcanalium was not found
# vulcanus was not found
# vulcanus was not found
# Uulcania was not found
# Uulcaniam was not found
# Uulcaniis was not found
# vulcanus was not found
# Uulcanium was not found
# Uulcanius was not found
# vulcanus was not found
# vulcanus was not found
# vulcanus was not found
# Uulcati was not found
# Uulcatium was not found
# Uulcatius was not found
# latin_variations/verb/vulgo/
# Uulne was not found
# Uulsca was not found
# Uulsci was not found
# Uulscis was not found
# Uulscorum was not found
# Uulscos was not found
# Uulsin was not found
# Uulsiniense was not found
# Uulsiniensem was not found
# Uulsinienses was not found
# Uulsiniis was not found
# Uulteio was not found
# Uulteius was not found
# latin_variations/noun/vultus/
# latin_variations/noun/vultus/
# latin_variations/noun/vulturnus/
# latin_variations/noun/vulturnus/
# latin_variations/noun/vulturnus/
# latin_variations/noun/vultur/
# latin_variations/proper noun/Uxama/
# latin_variations/noun/uxor/
# latin_variations/noun/uxor/
# Uzalis was not found
# Uzalitanum was not found
# Xuuiros was not found
# Xxuiro was not found
# Xan was not found
# Xanthiam was not found
# Xanthippae was not found
# latin_variations/proper noun/Xanthippe/
# Xanthippo was not found
# Xanthippum was not found
# latin_variations/proper noun/Xanthippus/
# Xantho was not found
# Xanthoque was not found
# Xanthos was not found
# Xanthum was not found
# latin_variations/proper noun/Xanthus/
# Xe was not found
# Xenagoras was not found
# Xenarchi was not found
# Xenarchum was not found
# Xenippa was not found
# Xeno was not found
# Xenocles was not found
# Xenoclide was not found
# Xenoclides was not found
# Xenocra was not found
# Xenocrate was not found
# Xenocratem was not found
# Xenocraten was not found
# Xenocratis was not found
# latin_variations/further reading/xenon/
# latin_variations/noun/xenon/
# latin_variations/further reading/xenon/
# latin_variations/noun/xenon/
# latin_variations/further reading/xenon/
# latin_variations/noun/xenon/
# Xenophanto was not found
# Xenophili was not found
# Xenophilo was not found
# Xenophilus was not found
# latin_variations/proper noun/Xenophon/
# Xenophontas was not found
# Xenophonte was not found
# Xenophontem was not found
# Xenophonteo was not found
# Xenophonti was not found
# Xenophontis was not found
# Xerolibyam was not found
# Xerolibyen was not found
# Xerse was not found
# Xersem was not found
# Xersen was not found
# Xerses was not found
# Xersis was not found
# Xerxe was not found
# Xerxem was not found
# Xerxemque was not found
# Xerxen was not found
# Xerxeque was not found
# latin_variations/noun/Xerxes/
# latin_variations/noun/Xerxes/
# Xerxi was not found
# Xifidio was not found
# Xutho was not found
# Xuthum was not found
# Xy was not found
# Xychi was not found
# Xychus was not found
# Xylinen was not found
# Xynium was not found
# Ymetto was not found
# Ypacares was not found
# Ypsicrates was not found
# Za was not found
# Zaba was not found
# Zabinaeo was not found
# Zac was not found
# Zacorum was not found
# Zacyn was not found
# Zacynthii was not found
# Zacynthios was not found
# Zacynthium was not found
# Zacyntho was not found
# Zacynthos was not found
# Zacynthum was not found
# Zacynthumque was not found
# latin_variations/proper noun/Zacynthus/
# Zagrus was not found
# Zalaces was not found
# Zaleuci was not found
# Zaleucum was not found
# Zalmoxi was not found
# latin_variations/proper noun/Zama/
# Zamae was not found
# Zamam was not found
# Zamensi was not found
# Zamensibus was not found
# Zanclaea was not found
# Zanclaeis was not found
# Zancleia was not found
# Zanclen was not found
# Zao was not found
# Zarasparum was not found
# Zarathensem was not found
# Zaratum was not found
# Zariaspen was not found
# latin_variations/proper noun/Zariasta/
# Zariastes was not found
# latin_variations/proper noun/Zarotis/
# Zathene was not found
# latin_variations/proper noun/Zazata/
# Ze was not found
# Zebedaei was not found
# Zefyro was not found
# Zefyrus was not found
# latin_variations/verb/zelo/
# Zelasium was not found
# latin_variations/proper noun/Zeno/
# Zenobiae was not found
# Zenobiam was not found
# Zenodoro was not found
# Zenodoti was not found
# latin_variations/proper noun/Zenon/
# Zenona was not found
# Zenone was not found
# Zenonem was not found
# Zenones was not found
# Zenoni was not found
# Zenonique was not found
# Zenonis was not found
# Zenothemis was not found
# Zephirum was not found
# Zephyri was not found
# Zephyriam was not found
# Zephyrio was not found
# Zephyrion was not found
# Zephyrique was not found
# Zephyris was not found
# Zephyritidis was not found
# Zephyritis was not found
# latin_variations/proper noun/Zephyrium/
# Zephyro was not found
# Zephyroque was not found
# Zephyros was not found
# Zephyrosque was not found
# Zephyrum was not found
# Zephyrumque was not found
# Zephyrusque was not found
# latin_variations/proper noun/Zerbis/
# Zernensium was not found
# Zerynthia was not found
# Zet was not found
# Zeten was not found
# Zetes was not found
# Zetesque was not found
# Zethi was not found
# Zetho was not found
# Zethum was not found
# Zethus was not found
# Zeton was not found
# Zetus was not found
# Zeu was not found
# Zeugitana was not found
# latin_variations/proper noun/Zeugma/
# Zeugmaque was not found
# Zeugmate was not found
# Zeuma was not found
# Zeumate was not found
# Zeusis was not found
# Zeuxiaden_ was not found
# Zeuxidae was not found
# Zeuxide was not found
# Zeuxidem was not found
# Zeuxidi was not found
# Zeuxidos was not found
# Zeuxim was not found
# Zeuxin was not found
# Zeuxip was not found
# Zeuxippes was not found
# Zeuxippi was not found
# Zeuxippo was not found
# Zeuxippum was not found
# Ziboeta was not found
# Ziboetam was not found
# Ziela was not found
# latin_variations/proper noun/Zimara/
# Zimaram was not found
# latin_variations/proper noun/Zimyra/
# Ziobetis was not found
# Zmarre was not found
# Zmil was not found
# Zmin was not found
# Zmint was not found
# Zminthea was not found
# Zmyr was not found
# latin_variations/proper noun/Zmyrna/
# latin_variations/proper noun/Zmyrna/
# Zmyrnaea was not found
# Zmyrnaei was not found
# Zmyrnaeis was not found
# Zmyrnaeorum was not found
# Zmyrnaeos was not found
# Zmyrnaeosque was not found
# Zmyrnaeum was not found
# Zmyrnaeus was not found
# latin_variations/proper noun/Zmyrna/
# Zoaranda was not found
# Zoili was not found
# Zoilo was not found
# Zoilum was not found
# Zoilus was not found
# Zoippi was not found
# Zoippo was not found
# Zoippum was not found
# Zoippus was not found
# latin_variations/proper noun/Zone/
# Zopyrion was not found
# Zopyro was not found
# Zopyrum was not found
# latin_variations/proper noun/Zopyrus/
# Zoro was not found
# Zoroast was not found
# Zoroastre was not found
# Zoroastren was not found
# Zoroastres was not found
# Zoroastri was not found
# Zorsines was not found
# Zorsini was not found
# Zosas was not found
# Zosimi was not found
# Zosimionem was not found
# Zosippus was not found
# Zostera was not found
# latin_variations/proper noun/Zotha/
# Zoticus was not found
# Zygiam was not found
# latin_variations/proper noun/Zyras/

# %%
###### HELPER FUNCTIONS#######


def path_to_folder(path):
    # converts non folders into folders 
    #aka just adds a slash to the end, if you dont give it a folder then it will probably produce an errror
    root = f"{path}"
    if root[-1] != "/":
        root+="/"
    return root

    
def get_each_file_in_folder(path):
    # this only takes in a folder path
    #RETURNS A FILE LIST 
    filelist =[]
    root =path_to_folder(path)    
    for subdir, dirs, files in os.walk(root):
        for file in files:
            f = os.path.join(subdir, file)
            filelist.append(f)
    return filelist
            
            
      
def get_each_csv_in_folder(path):
    # takes in Noun, Adjective,Verb
    #Returns All csv's in a folder
    filelist =[]
    root =path_to_folder(path)    
    for subdir, dirs, files in os.walk(root):
        for file in files:
            f = os.path.join(subdir, file)
            if f.endswith('.csv'):
                filelist.append(f)
    return filelist
    
def get_each_df_in_folder(path):
    #Takes in a folder 
    #Gets every dataframe in a folder 
    dflist =[]
    root =path_to_folder(path)    
    for f in get_each_csv_in_folder(path):
        df = pd.read_csv(f).fillna('')

        dflist.append(df)
    return dflist
'''
def get_greek_df(path):
    # takes in Noun, Adjective,Verb
    #print("test")
    dflist =[]
    root =to_folder(path)    
    for f in get_each_csv_in(path):
        df = pd.read_csv(f)
        greekdf=GreekCsv(f,df)
        dflist.append(greekdf)
    return dflist
'''
# get greek words from dictionary
def get_words_from_dict(path):
    wordlist = []
    for df in get_each_df_in_folder(path):
        for i in df.index:
             wordlist.append(df.iloc[i,1])
    return wordlist
   
#reads all csv and intializes all words into variations
def init_variations(path):
    # takes in a folder path
    # goes though every word in a dictionary and generates the variations of that word
    for word in get_words_from_dict(path):
        #display(df.iloc[i,1])
        generate_variations(word)

def match_words_in_folder(searchpath,wordpath):
#takes in a search path and a word path it will read a word from the word path and then find all 
#files in each folder that contains that word 
    filelist = []
    searchpath= path_to_folder(searchpath)
    for word in get_words_from_dict(wordpath):
        if(os.path.exists(searchpath + word)):
            filelist.append(get_each_file_in_folder(searchpath + word))
    flat_list = [item for sublist in filelist for item in sublist]
    return flat_list
    
def get_each_df_from_path_list(filelist):
    #takes in a list of csv paths and outputs a list of dataframes
    dflist=[]
    for file in filelist:
        df = pd.read_csv(file).fillna('')
        dflist.append(df)
    return dflist
    
def display_list(list):
# takes in a list of dataframes and displays the data
    for i in list:
        display(i)
        
def display_all():
    init_variations("dictionary/")
    matchedwords= match_words_in_folder("variations/")
    display_list(get_each_df_from_path_list(matchedwords))




def get_indices(df,words):
    # returns a tuple of 2 lists that contain the row indexes and column inexes for each column and row that this word is present in
    # convert to take in a list of words
    columns=[]
    rows = []
    for columnIndex in range(df.shape[1]):
        if(isinstance(words, list)):
            for word in words:
                rowIndex = df.index[df.iloc[:, columnIndex].str.contains(word)].tolist()
                if(rowIndex):
                    columns.append(columnIndex)
                    rows.append(rowIndex)
        else:
            rowIndex = df.index[df.iloc[:, columnIndex].str.contains(words)].tolist()
            if(rowIndex):
                columns.append(columnIndex)
                rows.append(rowIndex)
            
            #remove duplicates
    
    rows = [item for sublist in rows for item in sublist]
    rows = [*set(rows)]
    #print("COLUMNINDEXES ",columns)
    #print("ROWINDEXES ",rows)
    return (rows,columns)


def get_items(dflist,row_words,column_words=''):
    # takes in a tuple of index arrays
    # empty strings are used to indicate not input standard input is either a string or array of strings
    dflist2=[]
    if (row_words=='' and column_words==''):
            print('please put a word to search in columns or rows')
            return []
    
    for df in dflist:#
        row_indexes = get_indices(df,row_words)[0]
        column_indexes = get_indices(df,column_words)[1]
        if (row_words=='' and column_words!=''):
            df2 =df.iloc[:,column_indexes]
        if (row_words!='' and  column_words==''):
            df2 =df.iloc[row_indexes]
            
        df2 =df.iloc[row_indexes,column_indexes]
        
        dflist2.append(df2)
    return dflist2

# a function that checks if a string contains a number 
def contains_number(string):
    return any(char.isdigit() for char in string)


# not activley used will generate every possible combination kinda slow
def generate_all_accusative_scentences(verbs,nouns,sentiment):
    # takes in a verb dflist and noundf list aswell as asentiment
    sentiment = sentiment.lower()
    with open(f"latin_accusative_{sentiment}.txt.atepc","w+",encoding="utf-8") as f:
        for verbdf in verbs:
            for column_index in range(1,3):
                for row_index in range(verbdf.shape[0]):
                    verb =verbdf.iat[row_index,column_index]
                    if(verb=='' or contains_number(verb)):
                        continue
                    for noundf in nouns:
                        for column_index2 in range(1,noundf.shape[1]):
                            for row_index2 in range(noundf.shape[0]):
                                noun =noundf.iat[row_index2,column_index2]
                                
                                if(noun== '' or contains_number(noun)):
                                    continue
                                for word in verb.split(" "):
                                    f.write(word+" O -100\n")
                                    #print(word+" O -999")
                                for i,word in enumerate(noun.split(" ")):
                                    if(sentiment =="positive" ):
                                        if(i==0):
                                            f.write(word +" B-ASP Positive\n")
                                            #print(word +" B-ASP Positive")
                                        else:
                                            f.write(word +" I-ASP Positive\n")
                                            #print(word +" I-ASP Positive")
                                    elif(sentiment =="negative" ):
                                        if(i==0):
                                            f.write(word +" B-ASP Negative\n")
                                            #print(word +" B-ASP Negative")
                                        else:
                                            f.write(word +" I-ASP Negative\n")
                                            #print(word +" B-ASP Negative")
                                f.write(". O -100\n\n")
                                #print(". O -999")
                      
# WHATS MAINLY USED FOR NOW    -------------------------------------------------------------------------           
def generate_random_accusative_dataset(verbs,nouns,sentiment,num):
    # takes in a verb dflist and noundf list aswell as asentiment
    # takes in number of examples to output
    #randomly selects a verb noun pair
    with open(f"latin_accusative_{sentiment}.txt.atepc","w+",encoding="utf-8") as f:
        random_verb_dfs = random.choices(verbs,k=num)
        random_noun_dfs = random.choices(nouns,k=num)
        #
        i = 0
        num_tries=0
        while i <num:
            random_verb_row = random.randrange(0,random_verb_dfs[i].shape[0])
            random_verb_column = random.randrange(1,random_verb_dfs[i].shape[1])
            random_noun_row = random.randrange(0,random_noun_dfs[i].shape[0])
            random_noun_column = random.randrange(1,random_noun_dfs[i].shape[1])
            
            verb =strip_accents_and_lowercase(
            random_verb_dfs[i].iat[ random_verb_row,random_verb_column])
            
            noun =strip_accents_and_lowercase(random_noun_dfs[i].iat[ random_noun_row,random_noun_column])
            #print(verb)
            if((noun== '' or contains_number(noun)or
            verb=='' or contains_number(verb))
            and num_tries<20 ):
                print("COULDNT FIND NUMBER OF TRIES:", num_tries)
                num_tries+=1
                continue
            num_tries = 0
            f.write("[ O -999\n")# add brackets
            for word in verb.split(" "):
                f.write(word+" O -999\n")
            for j,word in enumerate(noun.split(" ")):
                if(sentiment =="positive" ):
                    if(j==0):
                        f.write(word +" B-ASP Positive\n")
                        #print(word +" B-ASP Positive")
                    else:
                        f.write(word +" I-ASP Positive\n")
                        #print(word +" I-ASP Positive")
                elif(sentiment =="negative" ):
                    if(j==0):
                        f.write(word +" B-ASP Negative\n")
                        #print(word +" B-ASP Negative")
                    else:
                        f.write(word +" I-ASP Negative\n")
                        #print(word +" B-ASP Negative")
            f.write("] O -999\n\n")
            #randomly select item or randomly select row and column
            #check if its valid if its not randomly get another pai
            i+=1
            
#WHATS MAINLY USED FOR NOW
def generate_random_nominative_dataset(noun_dfs,verb_dfs,adjective_dfs,sentiment,num):
    # takes in a verb dflist and noundf list aswell as asentiment
    # takes in number of examples to output
    #randomly selects a verb noun pair
    #mathc linking plurality 
    with open(f"latin_nominative_{sentiment}.txt.atepc","w+",encoding="utf-8") as f:
        random_noun_dfs = random.choices(noun_dfs,k=num)
        if(isinstance(verb_dfs, list)):
            random_verb_dfs = random.choices(verb_dfs,k=num)
        random_adjective_dfs = random.choices(adjective_dfs,k=num)
        gramatical_number=["1 sg","2 sg","3 sg","1 pl","2 pl","3 pl"]
        
        #
        i = 0
        num_tries=0
        while i <num:
            random_gramatical_number = random.choice(gramatical_number)
            
            
            random_noun_row = random.randrange(0,random_noun_dfs[i].shape[0])
            random_noun_column = random.randrange(1,random_noun_dfs[i].shape[1])
            #random_noun_column = get_indices(random_noun_dfs[i],random_gramatical_number)
            
            #random_verb_row = get_indices(random_verb_dfs[i],random_gramatical_number)
            if(isinstance(verb_dfs, list)):
                random_verb_row = random.randrange(0,random_verb_dfs[i].shape[0])
                random_verb_column = random.randrange(1,random_verb_dfs[i].shape[1])
            
            random_adjective_row = random.randrange(0,random_adjective_dfs[i].shape[0])
            random_adjective_column = random.randrange(1,random_adjective_dfs[i].shape[1])
            
            noun =strip_accents_and_lowercase(
            random_noun_dfs[i].iat[ random_noun_row,random_noun_column])
            
            if(isinstance(verb_dfs, list)):
                verb =random_verb_dfs[i].iat[ random_verb_row,random_verb_column]
            else:
                verb =verb_dfs
            
            adjective =strip_accents_and_lowercase(
            random_adjective_dfs[i].iat[ random_adjective_row,random_adjective_column])
           
            #print(verb)
            if((noun== '' or contains_number(noun)or
            verb=='' or contains_number(verb)or 
            adjective=='' or contains_number(adjective))
            and num_tries<20 ):
                print("COULDNT FIND NUMBER OF TRIES:", num_tries)
                num_tries+=1
                continue
            num_tries = 0
            f.write("[ O -999\n")# add brackets so that stuff doesnt break when put into the 
            for j,word in enumerate(noun.split(" ")):
                if(sentiment =="positive" ):
                    if(j==0):
                        f.write(word +" B-ASP Positive\n")
                        #print(word +" B-ASP Positive")
                    else:
                        f.write(word +" I-ASP Positive\n")
                        #print(word +" I-ASP Positive")
                elif(sentiment =="negative" ):
                    if(j==0):
                        f.write(word +" B-ASP Negative\n")
                        #print(word +" B-ASP Negative")
                    else:
                        f.write(word +" I-ASP Negative\n")
                        #print(word +" B-ASP Negative")
            for word in verb.split(" "):
                f.write(word+" O -999\n")
            for word in adjective.split(" "):
                f.write(word+" O -999\n")
            f.write("] O -999\n\n") 
            #randomly select item or randomly select row and column
            #check if its valid if its not randomly get another pai
            i+=1
# FUNCTION GETS A RANDOM SAMPLE OUTPUTS AN ARRAY OF STUFF
def random_sample(path,num):
#READS A RANDOM SAMPLE FROM A FILE AND APPENDS IT TO AN ARRAY
    sample = []
    with open(path,"r",encoding="utf-8") as f:
    
        data = f.read().split('\n\n')
        for i in range (num):
            sample.append(random.choice(data))
            
        # read untill double new line
        # append string to array
    return sample

def sample_to_dataset(sample,name):
# ideally every entry inside of the array should be a complete dataset entry ready to be outputted directly into a file one after another
    with open(name,"+w",encoding="utf-8") as f:
        for s in(sample):
            f.write(f"{s}\n\n")

def shuffle_datasets(paths,type='test',num=2000):
#shuffle all datasets in the paths given to it and then outputs it into a new file
    combined = []
    for p in paths:
        pos =random_sample(f"{p[0]}",int(num/(2*len(paths))))
        neg =random_sample(f"{p[1]}",int(num/(2*len(paths))))
        combined += pos+neg
    random.shuffle(combined)
    sample_to_dataset(combined,f"latin.{type}.txt.atepc")
    
    
    

#nomitiv
#negation
#conjunction

# %%
#get_each_file_in("dictionary/nouns")
#get_each_csv_in("dictionary/nouns")
#init_variations_in("dictionary/nouns")
#matchedwords= match_words_in("variations/noun","dictionary/nouns")

# THIS FUNCTION PIECES TOGETHER A RANDOM SAMPLE OF DECLINED WORDS TO CREATE A ACCUSATIVE SCENTENCE
def test_create_accusative(init=False,randomize=True,debug=False):
    # INIIT VARAIATIONS CREATES THE GREEK VARIATIONS FOLDER
    if (init==True or not os.path.exists("latin_variations/")):
        init_variations("latin_dictionary/nouns") 
        init_variations("latin_dictionary/verbs/actionverbs/negative")
        init_variations("latin_dictionary/verbs/actionverbs/positive")
        #init_variations_in("greek_dictionary/adjectives/positive")
        #init_variations_in("greek_dictionary/adjectives/negative")


    #'''
    # searches the words in the greek varations folder for nouns
    matchednouns= match_words_in_folder("latin_variations/noun","latin_dictionary/nouns")

    #display_list(get_accustive_nouns(path_to_df(matchednouns)))


    matchedverbs_pos= match_words_in_folder("latin_variations/verb","latin_dictionary/verbs/actionverbs/positive")
    print(matchedverbs_pos)
    matchedverbs_neg= match_words_in_folder("latin_variations/verb","latin_dictionary/verbs/actionverbs/negative")
    print(matchedverbs_neg)
    ##display_list(path_to_df(matchedwords))

    #display_list(get_present_singular_verbs(path_to_df(matchedverbs_neg)))

    #if debug:display_list(path_to_df(matchedverbs_pos))
    #verbs_pos=get_present_singular_verbs(path_to_df(matchedverbs_pos))
    verbs_pos = get_items(get_each_df_from_path_list(matchedverbs_pos),["indicative","present"],"singular")
   # print(f"get_each_df_from_path_list {get_each_df_from_path_list(matchedverbs_pos)}")
    print(f"Verbs_Pos {verbs_pos}")
    verbs_neg=get_items(get_each_df_from_path_list(matchedverbs_neg),["indicative","present"],"singular")
   # print(f"get_each_df_from_path_list {get_each_df_from_path_list(matchedverbs_neg)}")
    print(f"Verbs_neg {verbs_neg}")
    #nouns=get_accustive_nouns(path_to_df(matchednouns))
    #nouns=return_rows_that_contain(['accusative','nominative'],path_to_df(matchednouns))
    nouns=get_items(get_each_df_from_path_list(matchednouns),'accusative')
    #display(nouns)
    if debug:display_list(nouns)
    if debug:display_list(verbs_pos)
    if(randomize == True):

      print('test')
      generate_random_accusative_dataset(verbs_pos,nouns,"positive",1000)
      generate_random_accusative_dataset(verbs_neg,nouns,"negative",1000)
        #generate_all_accusative_scentences(verbs_pos,nouns,"positive")
        #generate_all_accusative_scentences(verbs_neg,nouns,"negative")
      '''
      neg =random_sample("accusative_negative.txt.atepc",1000)
      pos=random_sample("accusative_positive.txt.atepc",1000)
      combined = neg+pos
      random.shuffle(combined)
      sample_to_dataset(combined,"greek.test.txt.atepc")


      generate_random_accusative_dataset(verbs_pos,nouns,"positive",1000)
      generate_random_accusative_dataset(verbs_neg,nouns,"negative",1000)

      neg2 =random_sample("accusative_negative.txt.atepc",1000)
      pos2=random_sample("accusative_positive.txt.atepc",1000)
      combined2 = neg2+pos2
      random.shuffle(combined2)
      sample_to_dataset(combined2,"greek.train.txt.atepc")
      '''
    else:
      generate_all_accusative_scentences(verbs_pos,nouns,"positive")
      generate_all_accusative_scentences(verbs_neg,nouns,"negative")
        
    
#---------------------------
# THIS FUNCTION PIECES TOGETHER A RANDOM SAMPLE OF DECLINED WORDS TO CREATE A NOMINATIVCE SCENTENCE
def test_create_nominative(init=False,randomize=True,debug=False):
    if (init==True or not os.path.exists("latin_variations/")):
        init_variations("latin_dictionary/nouns")
        init_variations("latin_dictionary/verbs/linkingverbs/")
        init_variations("latin_dictionary/adjectives/positive")
        init_variations("latin_dictionary/adjectives/negative")


    #'''

    matchednouns= match_words_in_folder("latin_variations/noun","latin_dictionary/nouns")

    #display_list(get_accustive_nouns(path_to_df(matchednouns)))


    matchedverbs= match_words_in_folder("latin_variations/verb","latin_dictionary/verbs/linkingverbs/")
    matched_adj_pos= match_words_in_folder("latin_variations/adjective","latin_dictionary/adjectives/positive")
    matched_adj_neg= match_words_in_folder("latin_variations/adjective","latin_dictionary/adjectives/negative")
    

    ##display_list(path_to_df(matchedwords))

    #display_list(get_present_singular_verbs(path_to_df(matchedverbs_neg)))

    #if debug:display_list(path_to_df(matchedverbs_pos))
    #verbs_pos=get_present_singular_verbs(path_to_df(matchedverbs_pos))
    nouns=get_items(get_each_df_from_path_list(matchednouns),'nominative')
    #verbs=get_items(path_to_df(matchedverbs),["sg","pl"],"present")
    #display_list(path_to_df(matchedverbs))
    #verbs=get_items(path_to_df(matchedverbs),"infinitive","active")
    verbs= strip_accents_and_lowercase("sum")

    adjectives_pos=get_items(get_each_df_from_path_list(matched_adj_pos),"nominative")
    adjectives_neg=get_items(get_each_df_from_path_list(matched_adj_neg),"nominative")
    #nouns=get_accustive_nouns(path_to_df(matchednouns))
    #nouns=return_rows_that_contain(['accusative','nominative'],path_to_df(matchednouns))
   
    #display(nouns)
    #if debug:display_list(nouns)
    #if debug:display_list(verbs)
    #if debug:display_list(adjectives_pos)
    if(randomize == True):
        generate_random_nominative_dataset(nouns,verbs,adjectives_pos,"positive",1000)
        generate_random_nominative_dataset(nouns,verbs,adjectives_neg,"negative",1000)
        #generate_all_accusative_scentences(verbs_pos,nouns,"positive")
        #generate_all_accusative_scentences(verbs_neg,nouns,"negative")
        '''
        neg =random_sample("nominative_negative.txt.atepc",1000)
        pos=random_sample("nominative_positive.txt.atepc",1000)
        combined = neg+pos
        random.shuffle(combined)
        sample_to_dataset(combined,"greek.test.txt.atepc")
        '''
        '''
        generate_random_nominative_dataset(nouns,verbs,adjectives_pos,"positive",1000)
        generate_random_nominative_dataset(nouns,verbs,adjectives_neg,"negative",1000)
        #generate_all_accusative_scentences(verbs_pos,nouns,"positive")
        #generate_all_accusative_scentences(verbs_neg,nouns,"negative")
        
        neg =random_sample("nominative_negative.txt.atepc",1000)
        pos=random_sample("nominative_positive.txt.atepc",1000)
        combined = neg+pos
        random.shuffle(combined)
        sample_to_dataset(combined,"greek.train.txt.atepc")
        '''
        
    else:
        pass
        #generate_all_accusative_scentences(verbs_pos,nouns,"positive")
        #generate_all_accusative_scentences(verbs_neg,nouns,"negative")

# %%
# TEST GENERATE IS A FUNCTION THAT CREATE
def testGenerate(filename ='test', initialize = False):
    # init is a parmeter that generates all of the declension csv's 
    #right now its a little innefficiant if the csv's are already initialized then you do not need to initialize so you can set to false and it will generate almost immediatley
     test_create_accusative(
     init=initialize,
     randomize=True,debug=True)
     
     test_create_nominative(
     init = initialize,
     randomize=True,debug=True)
     
     dataset_paths=[
          ["latin_accusative_positive.txt.atepc","latin_accusative_negative.txt.atepc"],
          ["latin_nominative_positive.txt.atepc","latin_nominative_negative.txt.atepc"]
          ]
     shuffle_datasets(dataset_paths,type=filename,num= 2000)

testGenerate(filename ='test',initialize = False) # set initialize to false if this is not your first time running for it to generate fast
testGenerate(filename ='train',initialize = False)

#this generates atepc files just open in a text editor download a text editor plugin for google drive to make it easier

# %%
pd.read_csv("latin_variations/verb/diligo/_conjugation.csv")

# %%
pd.read_csv("latin_variations/noun/romanus/_declension.csv")

# %%
matchednouns= match_words_in_folder("latin_variations/noun","latin_dictionary/nouns")
nouns=get_items(get_each_df_from_path_list(matchednouns), "accusative", "")
count = 0
for item in nouns:
  count += 1
nouns[0].Singular['3']
print('\n')
print(nouns[0])
#print(nouns[0].iloc[0])
#print(nouns[0].accusative['Singular'])
